# %%
import numpy as np
from astropy.io import fits
from scipy.optimize import curve_fit
import os
import glob
from pylab import *
from math import e
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.ndimage import rotate
from PIL import Image
import pandas as pd

from datetime import datetime

# %%
notes = "early test"

# %%
#path1  = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/temp/*.bmp"
#path1  = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20250917/*.bmp"
#path1 = "/Users/anh5866/OneDrive - The Pennsylvania State University/20250917/*.bmp"


#change for each file
foldername_date = "20251020"
foldername = "morning5237"

#change to your path 
filepath = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/" + foldername_date + "/" + foldername
path1 = filepath + "/*.bmp"

bmp_list = glob.glob(path1)
bmp_list = np.sort(bmp_list,kind='standardsort')

print(bmp_list)
print(len(bmp_list))
# Out:
# ['/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020/morning5237/morning0001 25-10-20 10-14-03.bmp'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020/morning5237/morning0002 25-10-20 10-14-03.bmp'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020/morning5237/morning0003 25-10-20 10-14-03.bmp'
#  ...
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020/morning5237/morning4131 25-10-20 10-17-02.bmp'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020/morning5237/morning4132 25-10-20 10-17-02.bmp'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020/morning5237/morning4133 25-10-20 10-17-02.bmp']
# 4133

# %%
nested_folder_path = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/" + foldername_date + "_data"
try:
    os.makedirs(nested_folder_path, exist_ok=True) # exist_ok=True prevents error if already exists
    print(f"Nested folder '{nested_folder_path}' created successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Nested folder '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data' created successfully.

# %%
nested_nested_folder_path = nested_folder_path + "/" + foldername
try:
    os.makedirs(nested_nested_folder_path, exist_ok=True) # exist_ok=True prevents error if already exists
    print(f"Nested folder '{nested_nested_folder_path}' created successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Nested folder '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237' created successfully.

# %%
filename = os.path.basename(filepath)
num_data = len(bmp_list)


#for i in range(len(bmp_list)):
#    print(str(bmp_list[i][-21:-4]))
    
creation_date_start = str(bmp_list[0][-21:-4])
creation_date_stop = str(bmp_list[-1][-21:-4])

# %%
filename = os.path.basename(filepath)
num_data = len(bmp_list)


print(filename)
print(num_data)
print(creation_date_start)
print(creation_date_stop)
print(notes)
# Out:
# morning5237
# 4133
# 25-10-20 10-14-03
# 25-10-20 10-17-02
# early test

# %%
csv_path = "/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/collimated_beam_entry.xlsx"

# %%
log_path = nested_nested_folder_path + "/" + filename + ".txt"

with open(log_path, "w") as f:
    f.write("Filename\tCreation Date\n")
    f.write("-----------------------------------\n")

    for bmp_file in bmp_list:
        #get timestamp 
        dt_str = bmp_file[-21:-4]   
        
        #convert timestamp string to  datetime object
        creation_date = datetime.strptime(dt_str, "%y-%m-%d %H-%M-%S")

        #writee filename and timestamp
        f.write(f"{os.path.basename(bmp_file)}\t{creation_date}\n")

print("Creation dates saved to {log_path}")
# Out:
# Creation dates saved to {log_path}

# %%
input_folder = filepath
output_folder = nested_nested_folder_path + "/" + foldername + "_fits"

print(input_folder)
print(output_folder)
# Out:
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020/morning5237
# /Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237/morning5237_fits

# %%
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".bmp"):
        #load bmp
        img_path = os.path.join(input_folder, filename)
        img = Image.open(img_path).convert("L")  
        data = np.array(img)

        #save as FITS
        fits_filename = os.path.splitext(filename)[0] + ".fits"
        fits_path = os.path.join(output_folder, fits_filename)
        hdu = fits.PrimaryHDU(data)
        hdu.writeto(fits_path, overwrite=True)

# %%
path2 = output_folder + "/*.fits"

fits_list = glob.glob(path2)
fits_list = np.sort(fits_list,kind='standardsort')

print(fits_list)
print(len(fits_list))
# Out:
# ['/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237/morning5237_fits/morning0001 25-10-20 10-14-03.fits'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237/morning5237_fits/morning0002 25-10-20 10-14-03.fits'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237/morning5237_fits/morning0003 25-10-20 10-14-03.fits'
#  ...
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237/morning5237_fits/morning4131 25-10-20 10-17-02.fits'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237/morning5237_fits/morning4132 25-10-20 10-17-02.fits'
#  '/Users/anh5866/Desktop/Coding/OGRE/collimated_beam/20251020_data/morning5237/morning5237_fits/morning4133 25-10-20 10-17-02.fits']
# 4133
